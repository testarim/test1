# %%
# %matplotlib widget
from XAFSanalysis import XAFSanalysis_func as func

#fileD='c:/users/bl14b1/data/dxafs/01'
#fileD=r'C:/Users/admin/.conda/envs/arim-xafs/testOrganizationRepository/03'
fileD='./03'
fileP='ad*'
fileE='.dat'
#savefileD=r'C:/Users/admin/.conda/envs/arim-xafs/testOrganizationRepository/03/fit'
savefileD='./03/fit'

# %% [markdown]
# <span style="font-size: 200%; color: black;">XAFSデータ解析</span>

# %% [markdown]
# <span style="font-size: 150%; color: black;">ファイル設定</span>

# %%
func.dataDset(fileD, fileP,fileE,savefileD)
# Out:
# VBox(children=(HBox(children=(Label(value='data directory'), Text(value='./03'), Label(value='data filename pa…
# Output()

# %% [markdown]
# <span style="font-size: 150%; color: black;">Normmalization, background removal, FT and fitting parameters</span>

# %%
func.Paramset()
func.pathlist()
# Out:
# HBox(children=(VBox(children=(HBox(children=(Label(value='E0'), BoundedFloatText(value=24381.7, layout=Layout(…
# Output()
# HBox(children=(BoundedIntText(value=1, description='No. of Paths', max=5, min=1), Dropdown(options=('path1', '…
# Output()

# %% [markdown]
# <span style="font-size: 150%; color: black;">Plot graphs of Norm, chik, FT and Fit</span>

# %%
func.plot_bkgchift()
# Out:
# interactive(children=(Dropdown(description='select', options=('xmu', 'chik', 'FT', 'Fitting'), value='xmu'), O…
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# <span style="font-size: 150%; color: black;">Fit and save all data</span>

# %%
func.fit_all()
# Out:
# VBox(children=(HBox(children=(Checkbox(value=False, description='norm'), Checkbox(value=False, description='ch…

# %%
import sys

print("{}{: >25}{}{: >10}{}".format('|','Variable Name','|','Memory','|'))
print(" ------------------------------------ ")
for var_name in dir():
    if not var_name.startswith("_") and sys.getsizeof(eval(var_name)) > 0: #ここだけアレンジ
        print("{}{: >25}{}{: >10}{}".format('|',var_name,'|',sys.getsizeof(eval(var_name)),'|'))

# %% [markdown]
# <span style="font-size: 150%; color: black;">Plot fitting results</span>

# %%
func.res_plot()
